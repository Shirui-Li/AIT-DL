# %% [markdown]
# <a href="https://colab.research.google.com/github/Shirui-Li/AIT-DL/blob/main/08_1D_CNN_activity_recognition_assessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Copyright
# <pre>
# You may use and modify this code for research and development purpuses.
# Using this code for educational purposes (self-paced or instructor led) without the permission of the author is prohibited.
# Copyright (c) 2023 Bálint Gyires-Tóth - All Rights Reserved
#
# </pre>

# %% [markdown]
# In this notebook, we will classify human activities based on smartphone accelerometer and gyroscope data. The corresponding Human Activity Recognition Using Smartphones Data Set is delivered by UCI Machine Learning Repository, for more information [please visit the site](https://archive.ics.uci.edu/ml/datasets/human+activity+recognition+using+smartphones).

# %% [markdown]
# ## 1. Data acquisition
# Lets download and unpack the data.

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00240/UCI%20HAR%20Dataset.zip
# Out:
# --2024-04-10 19:09:46--  https://archive.ics.uci.edu/ml/machine-learning-databases/00240/UCI%20HAR%20Dataset.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘UCI HAR Dataset.zip.4’
#
# UCI HAR Dataset.zip     [    <=>             ]  58.17M  90.5MB/s    in 0.6s
#
# 2024-04-10 19:09:46 (90.5 MB/s) - ‘UCI HAR Dataset.zip.4’ saved [60999314]

# %%
# !unzip "UCI HAR Dataset.zip" > null
# Out:
# replace UCI HAR Dataset/.DS_Store? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# ## 2. Imports
# In this notebook we will need the following packages.

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Activation, Dense, Flatten, Conv1D, MaxPooling1D, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import SGD
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 3. Loading the data
# The following functions will load the training and test data from the unpacked dataset.

# %%
# this function loads a single file (input or output)
def load_file(filepath):
  df = pd.read_csv(filepath, header=None, delim_whitespace=True)
  return df.values

# this function loads a set of files into a Numpy array with a shape of [samples, timesteps, features]
def load_group(filenames, prefix=''):
  loaded = list()
  for name in filenames:
    data = load_file(prefix + name)
    loaded.append(data)
    # stack group so that features are the 3rd dimension
  loaded = np.dstack(loaded)
  return loaded

 # load inputs and outputs from a directory
def load_XY(group, path):
  filepath = path + group + '/Inertial Signals/'
  filenames = list()
  filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt'] + \
               ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt'] + \
               ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
  # inputs
  X = load_group(filenames, filepath)
  # output (class)
  Y = load_file(path + group + '/y_'+group+'.txt')
  return X, Y

# load the dataset, returns train and test X and y elements
def load_dataset(path='UCI HAR Dataset/'):
  # load all train
  X_train, Y_train = load_XY('train', path)
  X_test,  Y_test  = load_XY('test', path)
  Y_train = to_categorical(Y_train - 1 ) # we need -1 to scale the categories between 0..5 (from 1..6)
  Y_test  = to_categorical(Y_test - 1 ) # we need -1 to scale the categories between 0..5 (from 1..6)
  return X_train, Y_train, X_test, Y_test

# %%
X_train, Y_train, X_test, Y_test = load_dataset()

# %%
X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
# Out:
# ((7352, 128, 9), (7352, 6), (2947, 128, 9), (2947, 6))

# %%
Y_train[0]
# Out:
# array([0., 0., 0., 0., 1., 0.], dtype=float32)

# %% [markdown]
# ## 3.1. Data exploration: target variable - exercise 1
# Let's check how many data instances there are for each class:

# %%
num_ones_per_category = np.sum(Y_train, axis=0)
print(num_ones_per_category)
# Out:
# [1226. 1073.  986. 1286. 1374. 1407.]

# %%
print("No. of instance belong to class 0:", num_ones_per_category[0])
print("No. of instance belong to class 1:", num_ones_per_category[1])
print("No. of instance belong to class 2:", num_ones_per_category[2])
print("No. of instance belong to class 3:", num_ones_per_category[3])
print("No. of instance belong to class 4:", num_ones_per_category[4])
print("No. of instance belong to class 5:", num_ones_per_category[5])
# Out:
# No. of instance belong to class 0: 1226.0
# No. of instance belong to class 1: 1073.0
# No. of instance belong to class 2: 986.0
# No. of instance belong to class 3: 1286.0
# No. of instance belong to class 4: 1374.0
# No. of instance belong to class 5: 1407.0

# %% [markdown]
# You can doublecheck your calculations by plotting the histogram of the target variables:

# %%
sns.histplot(np.argmax(Y_train,axis=1))
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ## 3.2. Data exploration: input variables - exercise 2
# And now let's select one instance from each class and plot the corresponding timeseries:

# %%
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(12, 6))

for i in range(2): # row
  for k in range(3): # column
    for l in range(X_train.shape[2]): # dimensons to be displayed
      class_no=i*2+k
      axs[i,k].plot(X_train[next(m for m in range(len(Y_train)) if np.argmax(Y_train[m]) == class_no)])
      axs[i,k].title.set_text("Class "+str(class_no))
plt.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# **I notice that the original code of this homework seems to have a calculation mistake in class_no, which results in two repetitive Class 2 graphs and no Class 5 graph. Thus, I fixed the calculation problem and plotted all 6 graphs again.**

# %%
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(12, 6))

for i in range(2): # row
  for k in range(3): # column
    for l in range(X_train.shape[2]): # dimensons to be displayed
      if i == 0:
        class_no=i*2+k
      else:
        class_no=i*2+k+1
      axs[i,k].plot(X_train[next(m for m in range(len(Y_train)) if np.argmax(Y_train[m]) == class_no)])
      axs[i,k].title.set_text("Class "+str(class_no))
plt.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## 4. Model definition and training - exercise 3

# %% [markdown]
# Let's define and train a 1D convolutional neural network, with the multidimensional timeseries as inputs, and the class in one-hot encoding as output.
#
# This time your task is to correct the code below and achieve higher than 90% validation accuracy and test accuracy. The test accuracy is calculated in section 5.
# Currently, **there are many errors (both syntactical and theroetical) in the model definition, compile and fit parts**, that should be fixed to achieve the goal. Don't change the number of layers and the layer types, and validation_split, just the other hyperparameters. There are several good solutions!
#
# Hints:
# * use narrow and deep Conv1D kernels
# * use standard activation functions for the inner layers (e.g. relu, sigmoid, tanh) with the corresponding initialization method
# * use the appropriate activation function the output and the corresponding loss function (which is aligned with the classification task)
# * use regularization, but not too agressive
# * use standard optimizers
# * train in mini-batches

# %%
nb_filter       = 3   # number of filter/kernels in the convolutional layers
filter_length   = 48  # length of the filter/kernel in the convolutional layers
window_size     = X_train.shape[1] # the window size defined by the dataset
nb_features     = X_train.shape[2] # the number of features of the input data
nb_outputs      = Y_train.shape[1] # the number of outputs (defined by the target data)

# %%
model = Sequential()
model.add(Conv1D(filters=nb_filter*3, kernel_size=filter_length, activation='relu', kernel_initializer='he_normal', input_shape=(window_size, nb_features)))
model.add(MaxPooling1D(pool_size=2, strides=1, padding="valid"))
model.add(Dropout(0.1))
model.add(Conv1D(filters=nb_filter*3, kernel_size=filter_length, activation='relu', kernel_initializer='he_normal'))
model.add(MaxPooling1D())
model.add(Dropout(0.1))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(nb_outputs, activation='softmax'))

# %% [markdown]
# Compiling the model with the appropriate loss function for multiclass classification.

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_12 (Conv1D)          (None, 81, 9)             3897
#
#  max_pooling1d_12 (MaxPooli  (None, 80, 9)             0
#  ng1D)
#
#  dropout_18 (Dropout)        (None, 80, 9)             0
#
#  conv1d_13 (Conv1D)          (None, 33, 9)             3897
#
#  max_pooling1d_13 (MaxPooli  (None, 16, 9)             0
#  ng1D)
#
#  dropout_19 (Dropout)        (None, 16, 9)             0
#
#  flatten_6 (Flatten)         (None, 144)               0
#
#  dense_12 (Dense)            (None, 128)               18560
#
#  dropout_20 (Dropout)        (None, 128)               0
#
#  dense_13 (Dense)            (None, 6)                 774
#
# =================================================================
# Total params: 27128 (105.97 KB)
# Trainable params: 27128 (105.97 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
es = EarlyStopping(patience=5, restore_best_weights=True, monitor="val_accuracy")

# %% [markdown]
# And now we run the training:

# %%
model.fit(X_train, Y_train,
          epochs=200, batch_size=128,
          validation_split=0.2, # don't change the validation split
          callbacks=[es],
          verbose=2)
# Out:
# Epoch 1/200
# 46/46 - 3s - loss: 1.2053 - accuracy: 0.5081 - val_loss: 0.7367 - val_accuracy: 0.7260 - 3s/epoch - 59ms/step
# Epoch 2/200
# 46/46 - 2s - loss: 0.4861 - accuracy: 0.8050 - val_loss: 0.5610 - val_accuracy: 0.8457 - 2s/epoch - 43ms/step
# Epoch 3/200
# 46/46 - 2s - loss: 0.2375 - accuracy: 0.9172 - val_loss: 0.4787 - val_accuracy: 0.8756 - 2s/epoch - 41ms/step
# Epoch 4/200
# 46/46 - 2s - loss: 0.1582 - accuracy: 0.9429 - val_loss: 0.4322 - val_accuracy: 0.8844 - 2s/epoch - 35ms/step
# Epoch 5/200
# 46/46 - 2s - loss: 0.1312 - accuracy: 0.9503 - val_loss: 0.3561 - val_accuracy: 0.9089 - 2s/epoch - 34ms/step
# Epoch 6/200
# 46/46 - 2s - loss: 0.1148 - accuracy: 0.9543 - val_loss: 0.3909 - val_accuracy: 0.9062 - 2s/epoch - 34ms/step
# Epoch 7/200
# 46/46 - 1s - loss: 0.1119 - accuracy: 0.9554 - val_loss: 0.4783 - val_accuracy: 0.9082 - 1s/epoch - 30ms/step
# Epoch 8/200
# 46/46 - 1s - loss: 0.1031 - accuracy: 0.9600 - val_loss: 0.4264 - val_accuracy: 0.9082 - 1s/epoch - 30ms/step
# Epoch 9/200
# 46/46 - 1s - loss: 0.1077 - accuracy: 0.9556 - val_loss: 0.3542 - val_accuracy: 0.9069 - 1s/epoch - 30ms/step
# Epoch 10/200
# 46/46 - 2s - loss: 0.0954 - accuracy: 0.9612 - val_loss: 0.4893 - val_accuracy: 0.9130 - 2s/epoch - 43ms/step
# Epoch 11/200
# 46/46 - 2s - loss: 0.0991 - accuracy: 0.9582 - val_loss: 0.4588 - val_accuracy: 0.9143 - 2s/epoch - 40ms/step
# Epoch 12/200
# 46/46 - 1s - loss: 0.0969 - accuracy: 0.9589 - val_loss: 0.4628 - val_accuracy: 0.9103 - 1s/epoch - 30ms/step
# Epoch 13/200
# 46/46 - 2s - loss: 0.0889 - accuracy: 0.9609 - val_loss: 0.4015 - val_accuracy: 0.9150 - 2s/epoch - 33ms/step
# Epoch 14/200
# 46/46 - 2s - loss: 0.1098 - accuracy: 0.9578 - val_loss: 0.5936 - val_accuracy: 0.9123 - 2s/epoch - 34ms/step
# Epoch 15/200
# 46/46 - 1s - loss: 0.0896 - accuracy: 0.9619 - val_loss: 0.6658 - val_accuracy: 0.9116 - 1s/epoch - 31ms/step
# Epoch 16/200
# 46/46 - 1s - loss: 0.0865 - accuracy: 0.9606 - val_loss: 0.6690 - val_accuracy: 0.9089 - 1s/epoch - 32ms/step
# Epoch 17/200
# 46/46 - 2s - loss: 0.0882 - accuracy: 0.9595 - val_loss: 0.5148 - val_accuracy: 0.9109 - 2s/epoch - 34ms/step
# Epoch 18/200
# 46/46 - 2s - loss: 0.0861 - accuracy: 0.9633 - val_loss: 0.5455 - val_accuracy: 0.9103 - 2s/epoch - 47ms/step

# %% [markdown]
# ## 5. Evaluation
# Please run the cells below to check the test loss and test accuracy (remember, the accuracy must be over 90%) and inspect the other evaluation methods as well.

# %%
eval = model.evaluate(X_test,Y_test)
print("Test loss:",eval[0])
print("Test accuracy:",eval[1])
# Out:
# 93/93 [==============================] - 0s 5ms/step - loss: 0.5835 - accuracy: 0.9050
# Test loss: 0.5834729075431824
# Test accuracy: 0.9049881100654602

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
preds = model.predict(X_test)
# Out:
# 93/93 [==============================] - 0s 4ms/step

# %%
print(classification_report(np.argmax(Y_test,1),np.argmax(preds,1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.94      0.96       496
#            1       0.98      0.92      0.95       471
#            2       0.88      0.99      0.93       420
#            3       0.82      0.81      0.81       491
#            4       0.79      0.84      0.81       532
#            5       1.00      0.95      0.97       537
#
#     accuracy                           0.90      2947
#    macro avg       0.91      0.91      0.91      2947
# weighted avg       0.91      0.90      0.91      2947

# %%
conf=confusion_matrix(np.argmax(Y_test,1),np.argmax(preds,1))
sns.heatmap(conf, annot=True, fmt='d', vmax=100)
# Out:
# <Axes: >
